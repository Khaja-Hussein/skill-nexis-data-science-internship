# %% [markdown]
# # Week 2 – SQL for Data Analysis

# %%
import pandas as pd
import sqlite3

# %%
df = pd.read_excel("SQL_Sales_Dataset_200_Rows.xlsx")
df.head()
# Out:
#    order_id  customer_name order_date   category sub_category    product_name  \
# 0      1000    Caleb Davis 2025-01-31   Clothing        Jeans       Jeans Try
# 1      1001  Misty Herrera 2025-05-05   Clothing        Jeans       Jeans New
# 2      1002      Rick Soto 2025-06-09   Clothing        Shoes        Shoes Us
# 3      1003      Sean Haas 2025-02-27  Furniture         Desk    Desk Section
# 4      1004       Ann Hall 2025-06-01  Furniture      Cabinet  Cabinet Center
#
#    quantity  unit_price  total_price region
# 0         2        1197         2394   West
# 1         9        1509        13581  South
# 2         5        1046         5230   East
# 3        10         292         2920  South
# 4         2         548         1096  North

# %%
conn = sqlite3.connect("sales_database.db")

df.to_sql("sales", conn, if_exists="replace", index=False)

print("SQL database created successfully!")
# Out:
# SQL database created successfully!

# %%
query = "SELECT * FROM sales LIMIT 5;"

result = pd.read_sql_query(query, conn)
result
# Out:
#    order_id  customer_name           order_date   category sub_category  \
# 0      1000    Caleb Davis  2025-01-31 00:00:00   Clothing        Jeans
# 1      1001  Misty Herrera  2025-05-05 00:00:00   Clothing        Jeans
# 2      1002      Rick Soto  2025-06-09 00:00:00   Clothing        Shoes
# 3      1003      Sean Haas  2025-02-27 00:00:00  Furniture         Desk
# 4      1004       Ann Hall  2025-06-01 00:00:00  Furniture      Cabinet
#
#      product_name  quantity  unit_price  total_price region
# 0       Jeans Try         2        1197         2394   West
# 1       Jeans New         9        1509        13581  South
# 2        Shoes Us         5        1046         5230   East
# 3    Desk Section        10         292         2920  South
# 4  Cabinet Center         2         548         1096  North

# %%
query = """
SELECT customer_name, SUM(total_price) AS total_spent
FROM sales
GROUP BY customer_name
ORDER BY total_spent DESC
LIMIT 10;
"""

result = pd.read_sql_query(query, conn)
result
# Out:
#         customer_name  total_spent
# 0       Lynn Garrison        47940
# 1       Debbie Turner        44990
# 2       Megan Charles        44620
# 3    Michelle Beltran        42471
# 4        Rick Sanford        41211
# 5      Patrick Watson        37680
# 6   Christopher Meyer        37320
# 7         Todd Barnes        36152
# 8  Stephanie Martinez        34576
# 9   Kimberly Alvarado        31752

# %%
query = """
SELECT AVG(total_price) AS average_order_value
FROM sales;
"""

result = pd.read_sql_query(query, conn)
result
# Out:
#    average_order_value
# 0            12100.535

# %% [markdown]
# ## Assignment Results
#
# ### Top 10 Customers
# The query identifies the top 10 customers based on their total spending.
#
# ### Average Order Value
# The average order value is **12,100.535**.
